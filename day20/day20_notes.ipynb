# %% [markdown]
# By using venv:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Installation:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task1_pydantic_models.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task2_structured_pipeline.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task3_entity_extraction.py

# %% [markdown]
# ![image.png](attachment:image.png)
