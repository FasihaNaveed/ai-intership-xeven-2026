# %% [markdown]
# Required Packages Install

# %% [markdown]
# pip install fastapi uvicorn sqlalchemy psycopg2-binary pydantic python-dotenv python-multipart passlib[bcrypt] python-jose langchain langchain-community langchain-openai faiss-cpu pypdf python-docx docx2txt streamlit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install fastapi uvicorn sqlalchemy psycopg2-binary pydantic python-dotenv python-multipart passlib[bcrypt] python-jose langchain langchain-community langchain-groq faiss-cpu pypdf python-docx docx2txt streamlit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# uvicorn src.main:app --reload

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://127.0.0.1:8000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://127.0.0.1:8000/docs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install email-validator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain langchain-community langchain-core langchain-groq langchain-huggingface sentence-transformers faiss-cpu pypdf python-docx docx2txt streamlit python-multipart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-huggingface

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-groq

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
