# %% [markdown]
# # Day 21 – Week 3 Review & Presentation

# %% [markdown]
# ## Objectives
#
# - Document Loading
# - Chunking
# - Embeddings
# - FAISS Search
# - Entity Extraction
# - Streamlit Deployment

# %% [markdown]
# ## Architecture Diagram
#
# Document
# ↓
# Loader
# ↓
# Chunker
# ↓
# Embeddings
# ↓
# FAISS
# ↓
# Semantic Search
# ↓
# Entity Extraction
# ↓
# Report

# %%
from analyzer import DocumentAnalyzer

result = DocumentAnalyzer(
    "../data/research_note.txt"
).run()

result

# %% [markdown]
# Create Virtual Environment & Install Packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After Processing:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python document_loader.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python chunker.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python embeddings_index.py:

# %% [markdown]
# Output of python entity_extraction.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python scripts/verify_pipeline.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After:
#
# pip install streamlit
#
# streamlit run app.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After uplaoding a pdf:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After uploading a txt file:

# %% [markdown]
# ![image.png](attachment:image.png)
