# %% [markdown]
# Virtual Environment Activate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Install Libraries

# %% [markdown]
# pip install faiss-cpu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install chromadb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-community

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-huggingface

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install sentence-transformers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install sentence-transformers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install pypdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install tiktoken

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install psutil

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Verification:
#
# pip list
#
# Huge list is shown

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python scripts/task1_faiss_operations.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Task 1: FAISS Setup & Basic Operations
#
# Objective
#
# Create a FAISS vector database and perform similarity search.
#
# Steps Performed
#
# Loaded embedding model.
#
# Created sample documents.
#
# Generated embeddings.
#
# Stored embeddings in FAISS.
#
# Performed similarity search.
#
# Saved index to disk.
#
# Reloaded index.
#
# Verified search after loading.
#
# Result
#
# FAISS successfully retrieved the most relevant documents based on semantic similarity.
#
# Learning Outcome
#
# Learned vector storage.
#
# Learned embeddings.
#
# Learned similarity search.
#
# Learned index persistence.
#
# Learned loading saved vector databases.

# %% [markdown]
# For task 2 Installation:

# %% [markdown]
# pip install langchain-text-splitters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python scripts/task2_document_library.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Task 2 Objective
#
# Build a searchable document library using FAISS.
#
# What Did
#
# Loaded text documents
#
# Added metadata
#
# Split documents into chunks
#
# Generated embeddings
#
# Stored vectors in FAISS
#
# Performed similarity search
#
# Applied metadata filtering
#
# Generated statistics file
#
# Why Chunking?
#
# Large documents cannot be embedded efficiently.
#
# Chunking breaks large documents into smaller pieces.
#
# Why Metadata?
#
# Metadata helps identify:
#
# Source file
#
# Section
#
# Page information
#
# Output
#
# Successfully retrieved top 5 relevant chunks based on user query.

# %% [markdown]
# Task 2: Document Library with FAISS
# Objective
#
# Build a searchable document library using FAISS vector database.
#
# Documents Used
# python.txt
# ai.txt
# machine_learning.txt
# databases.txt
# web_development.txt
# Steps Performed
# 1. Document Loading
#
# All text files were loaded into LangChain documents.
#
# 2. Metadata Added
#
# Each document received metadata:

# %%
source
section

# %% [markdown]
# Example:

# %%
{
  "source": "python.txt",
  "section": "general"
}

# %% [markdown]
# 3. Chunking
#
# Used:

# %%
RecursiveCharacterTextSplitter

# %% [markdown]
# Configuration:

# %%
chunk_size = 800
chunk_overlap = 100

# %% [markdown]
# Purpose:
#
# Large documents are broken into smaller chunks for better retrieval.
#
# 4. Embeddings
#
# Generated using:

# %%
sentence-transformers/all-MiniLM-L6-v2

# %% [markdown]
# 5. Vector Storage
#
# Stored embeddings inside FAISS vector database.
#
# 6. Similarity Search
#
# User query:

# %%
python

# %% [markdown]
# Retrieved top 5 most relevant chunks.
#
# 7. Metadata Filtering
#
# Filtered chunks from:

# %%
python.txt

# %% [markdown]
# 8. Statistics
#
# Generated:

# %%
stats.json

# %% [markdown]
# containing document and chunk information.

# %% [markdown]
# Install Chroma

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output of python scripts/task3_vector_store_comparison.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Result Analysis
#
# FAISS Performance
#
# Indexing Time
# 0.2085 seconds
# FAISS ne vectors bahut jaldi create kiye.
#
# Query Latency
# 0.0265 seconds
# Search response bahut fast tha.
#
# Advantages
#
# Fast indexing
#
# Fast retrieval
#
# Lightweight
#
# Local storage
#
# Chroma Performance
#
# Indexing Time
# 1.7825 seconds
# FAISS se slow tha.
#
# Query Latency
# 0.0399 seconds
# Search bhi thoda slow tha.
#
# Advantages
#
# Persistent storage
#
# Metadata management
#
# Production-friendly
#
# Easy collection management
#
# Final Comparison
#
# FAISS > Chroma
# Speed ke liye.
#
# Aur:
#
# Chroma > FAISS
# Features aur persistence ke liye.
