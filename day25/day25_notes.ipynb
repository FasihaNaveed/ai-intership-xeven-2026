# %% [markdown]
# Create Virtual Environment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Install Packages

# %% [markdown]
# pip install fastapi uvicorn python-multipart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-community

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-openai

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install faiss-cpu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install rank-bm25

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install pydantic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install python-dotenv

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install tiktoken

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install pypdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install sentence-transformers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install psutil

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What is Dense Retrieval?
#
# Uses embeddings.
#
# Example:
#
# Query:
#
# How does AI work?
#
# Embedding converts query into vector:
#
# [0.21,0.55,0.87....]
#
# FAISS searches similar vectors.
#
# This is called:
#
# Dense Retrieval
#
# Required by task.

# %% [markdown]
# What is Sparse Retrieval?
#
# Uses keywords.
#
# Example:
#
# Query:
#
# Python loops
#
# BM25 searches exact keywords.
#
# Required by task.

# %% [markdown]
# Implemented:
#
# Dense Retrieval (FAISS)
#
# Sparse Retrieval (BM25)
#
# Hybrid Retrieval
#
# Re-ranking Layer
#
# Why?
#
# Pure semantic search can miss keywords.
#
# Pure keyword search can miss meaning.
#
# Hybrid combines both.
#
# What happened?
#
# Query searches:
#
# FAISS → semantic meaning
#
# BM25 → exact keywords
#
# Results merged.
#
# Re-ranker filters best chunks.
#
# Why Re-ranking?
#
# Initial retrieval may contain irrelevant chunks.
#
# Re-ranking improves precision.

# %% [markdown]
# Dense Retrieval
#
# Current FAISS
#
# self.vectorstore.similarity_search()
#
# Uses embeddings.
#
# Meaning search.
#
# Sparse Retrieval
#
# BM25
#
# Uses keywords.
#
# Example:
#
# Query
#
# python loops
#
# Finds exact words.
#
# Hybrid Retrieval
#
# Combine both.
#
# 70%
# FAISS
#
# 30%
# BM25

# %% [markdown]
# Output  of uvicorn app.main:app --reload:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://127.0.0.1:8000/docs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
