# %% [markdown]
# 1. Python Data Types
# int → whole numbers → 10
# float → decimals → 10.5
# bool → True/False
# str → text → "Hello"

# %%
x = 10
y = 10.5
z = True
name = "Ali"

# %% [markdown]
# 2. Variables (PEP 8 rules)
#
# ✔ Good:

# %%
first_number = 10
student_name = "Ali"

# %% [markdown]
# ❌ Bad:

# %%
x = 10
a = "Ali"

# %% [markdown]
# 3. Input/Output

# %%
name = input("Enter your name: ")
print("Hello", name)

# %% [markdown]
# 4. Syntax Rules
# Indentation = 4 spaces
# Python is case sensitive
# Each statement line by line

# %% [markdown]
# 5. Comments

# %%
# single line comment

"""
multi-line comment
explains full block
"""

# %% [markdown]
# 6. Dynamic Typing

# %%
x = 10
x = "Hello"  # type changed

# %% [markdown]
# 7. Memory Concept (simple notes)
# int, float → stored as numeric objects
# str → stored as sequence of characters
# Python automatically manages memory (garbage collection)

# %% [markdown]
# 🔍 Research Sources
# 1. ChatGPT:
#
# 👉 Question:
# “Python memory management for data types”
#
# 📌 Key points:
#
# Python uses private heap memory
# Everything is an object
# Garbage collector removes unused objects
# 🔍 Research Sources
# 1. ChatGPT:
#
# 👉 Question:
# “Python memory management for data types”
#
# 📌 Key points:
#
# Python uses private heap memory
# Everything is an object
# Garbage collector removes unused objects
#
# 4. Article (Google search):
#
# Search:
# 👉 “Python data types memory management article”
