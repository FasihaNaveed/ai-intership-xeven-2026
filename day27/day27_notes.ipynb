# %% [markdown]
# Virtual Environment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Install packages

# %% [markdown]
# pip install fastapi uvicorn sqlalchemy pydantic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install pytest pytest-asyncio httpx

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://127.0.0.1:8000/docs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# uvicorn app.main:app --reload

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Why SQLite?
#
# SQLite lightweight hai aur development ke liye best hai.
#
# Baad mein:

# %%
DATABASE_URL = "postgresql://..."

# %% [markdown]
# kar ke PostgreSQL use karenge.

# %% [markdown]
# For Task 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For Task 3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# docker-compose up --build

# %% [markdown]
# ![image.png](attachment:image.png)
