# %% [markdown]
# Virtual Environment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Install Packages

# %% [markdown]
# pip install fastapi uvicorn python-multipart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# uvicorn main:app --reload

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# http://127.0.0.1:8000/docs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Test Create User

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Test Get All Users

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Test Update User (Same API)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Test Delete

# %% [markdown]
# ![image.png](attachment:image.png)
