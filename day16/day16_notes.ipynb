# %% [markdown]
# 📘 DAY 16 — LANGCHAIN
# 🚀 STEP 1: Install LangChain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After processing ends at:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# PDF LOADER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WEB LOADER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Installation issue solve

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1_basic_chain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2_prompt_template

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3_document_loader

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7_doc_qa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Openai Installation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After processing:

# %% [markdown]
# ![image.png](attachment:image.png)
