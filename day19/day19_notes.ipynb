# %% [markdown]
# Output for python scripts/task1_technique_comparison.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task2_template_library.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task3_output_control.py

# %% [markdown]
# ![image.png](attachment:image.png)
