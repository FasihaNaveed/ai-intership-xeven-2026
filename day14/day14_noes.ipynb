# %% [markdown]
# 1. Project idea
#
# “I built a contact management system using Python dictionaries and advanced data structures.”
#
# 2. Data structures used
#
# dict → main storage
#
# set → tags
#
# list → notes
#
# 3. Features
#
# Add, update, delete contacts
#
# Search with partial match
#
# Tag system
#
# Save/load using JSON
#
# 4. Concepts used
#
# functions
#
# comprehensions
#
# file handling
#
# sets/dicts/lists
#
# 5. Challenge
#
# “Managing nested data and converting sets for JSON was challenging.”

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
