# %% [markdown]
# Installation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After processing:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install langchain-community langchain-text-splitters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task1_compare_chunking.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task2_chunk_size_experiment.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Installation for task3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Output for python scripts/task3_smart_processor.py:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After setting correct route:

# %% [markdown]
# ![image.png](attachment:image.png)
