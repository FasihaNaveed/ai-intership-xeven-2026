# %% [markdown]
# # Environment Setup and First Python Script
#
# **Name:** Fasiha Naveed
#
# **Internship Day 1**
#
# This notebook documents the complete setup process of Python, VS Code, Jupyter Notebook, and execution of the first Python script.

# %% [markdown]
# # Objective
#
# The objective of this task is to:
#
# - Install Python
# - Install Visual Studio Code
# - Install Jupyter Extension
# - Configure Python environment
# - Create and run the first Python script
# - Document the complete setup process

# %% [markdown]
# # Software Installation
#
# The following software was installed:
#
# 1. Python
# 2. Visual Studio Code
# 3. Python Extension for VS Code
# 4. Jupyter Extension for VS Code
#
# These tools provide an environment for Python programming and AI development.

# %% [markdown]
# # Installation Steps
#
# ### Step 1
# Downloaded and installed Python.
#
# ### Step 2
# Installed Visual Studio Code.
#
# ### Step 3
# Installed Python Extension.
#
# ### Step 4
# Installed Jupyter Extension.
#
# ### Step 5
# Verified Python installation using:
#
# python --version

# %%
print("Hello! My name is Fasiha Naveed.")
print("I am an AI Engineer Intern at Xeven.")

# %% [markdown]
# # Running app.py
#
# The file app.py was created with the following code:
#
# print("Hello! My name is Fasiha Naveed.")
# print("I am an AI Engineer Intern at Xeven.")
#
# The script was executed successfully through the VS Code terminal.

# %% [markdown]
# # Screenshots
#
# ![image.png](attachment:image.png)
#
# 1. VS Code Home Screen
# 2. Installed Python Extension
# 3. Installed Jupyter Extension
# 4. app.py Source Code
# 5. Terminal Output
# 6. Jupyter Notebook Running Successfully

# %% [markdown]
# # Troubleshooting Notes
#
# ## Issue 1: Python Not Recognized
#
# Error:
#
# 'python' is not recognized as an internal or external command.
#
# Solution:
#
# Reinstall Python and enable "Add Python to PATH".
#
# ---
#
# ## Issue 2: Jupyter Kernel Not Found
#
# Solution:
#
# Install ipykernel using:
#
# pip install ipykernel
#
# ---
#
# ## Issue 3: Notebook Not Running
#
# Solution:
#
# Select the correct Python kernel from the top-right corner of the notebook.
